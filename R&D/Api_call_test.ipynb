# %%
import requests
import asyncio
import aiohttp
import copy
from datetime import datetime
from db_connector import DB
from logger import logging

Task_URL = "https://api.apify.com/v2/actor-tasks/yellow_saint~instagram-scraper-task/input?token=apify_api_qIc4Lwctqfr2WAFjmyQZ2mwd1zYhwO0JFLvE"
Scrape_Link_dataset = "https://api.apify.com/v2/actor-tasks/yellow_saint~instagram-scraper-task/run-sync-get-dataset-items?token=apify_api_qIc4Lwctqfr2WAFjmyQZ2mwd1zYhwO0JFLvE"
Insta_Link = 'https://www.instagram.com/{x}/'
inputs  =  requests.get(Task_URL)



#apify_client = ApifyClient(token)

# Start an actor and wait for it to finish
#task_call = apify_client.task('yellow_saint~instagram-scraper-task').call(task_input=obj_list[0])

# Fetch results from the actor run's default dataset
#dataset_items = apify_client.dataset(task_call['defaultDatasetId']).list_items().items

# %%
D = DB()
list_to_scan = D.pull(db = "Clean",document="Creators",filter= {},colunm={"_id":0,"username":1})
for j in list_to_scan:
    to_scan_dict = {"id":j["username"],"priority":1}
    D.push(to_scan_dict,"Clean","To_scan")

# %%
class Scrape():
    Task_URL = "https://api.apify.com/v2/actor-tasks/yellow_saint~instagram-scraper-task/input?token=apify_api_qIc4Lwctqfr2WAFjmyQZ2mwd1zYhwO0JFLvE"
    Scrape_Link_dataset = "https://api.apify.com/v2/actor-tasks/yellow_saint~instagram-scraper-task/run-sync-get-dataset-items?token=apify_api_qIc4Lwctqfr2WAFjmyQZ2mwd1zYhwO0JFLvE"
    Insta_Link = 'https://www.instagram.com/{x}/'
    


    def __init__(self) -> None:
        self.inputs  =  requests.get(self.Task_URL).json()
        self.DB = DB()
        logging.info("DB connected at Scraper")
        self.To_scan()
        
        
    def To_scan(self) -> list:
        Unsorted_list = self.DB.pull(db = "Clean",document="To_scan",filter= {},colunm={"_id":0,})
        sorted_data = sorted(Unsorted_list, key=lambda x: x['priority'])
        final_list = []
        for i in sorted_data:
            final_list.append(i["id"])
        self.To_scan = final_list    
        logging.info("To_scan listed Created")

    
    async def get(self,session: aiohttp.ClientSession,input_obj:dict,url : str) -> dict:

        print(f"Requesting {url}")
        resp = await session.request('POST', url=url,json=input_obj)

        # Note that this may raise an exception for non-2xx responses
        # You can either handle that here, or pass the exception through
        data = await resp.json()
        print(f"Received data for {url}")
        return data


    async def main(self,input_objs,url):
        # Asynchronous context manager.  Prefer this rather
        # than using a different session for each GET request
        async with aiohttp.ClientSession() as session:
            tasks = []
            for obj in input_objs:
                print(session)
                tasks.append(self.get(session=session, url=url,input_obj=obj))
            # asyncio.gather() will wait on the entire task set to be
            # completed.  If you want to process results greedily as they come in,
            # loop over asyncio.as_completed()
            data = await asyncio.gather(*tasks, return_exceptions=True)
            return data
    def Cleaner(self,data) -> None:
        """
            The Scrape function produces a data in the form of 2-d nested Lists -> list[list] 
            To pull the lists out of the main list we use 2 loops to pull them out
            can be done with recrusion but will try later,
            Also traverse the data to find more related profiles to further scan       
        """
        cleaned_data = []
        for i in data:
            for j in i:
                j["Date"] = datetime.today() 
                cleaned_data.append(j)
        self.DB.push_many(data=cleaned_data,db="Raw_data",document="Creators")

        for i in cleaned_data:

            for j in i["relatedProfiles"]:
                to_scan_dict = {"id":j["username"],"priority":2}
                self.DB.push(to_scan_dict,"Clean","To_scan")
            
      
                
    
    def url_maker(self) -> list:
        url_list = []
        for i in self.To_scan:
            url_list.append(Insta_Link.format(x=i))
        return url_list   
    def input_obj_maker(self) -> None:
        self.obj_list = []
        list_of_usernames = self.url_maker()
        block_size = 10
        print(block_size)
        blocks = [list_of_usernames[i:i+block_size] for i in range(0, len(list_of_usernames), block_size)]
        for i in blocks:
            temp = copy.deepcopy(self.inputs)
            temp["directUrls"] =  i
            self.obj_list.append(temp)  
    async def scrape(self):
        data = await self.main(self.obj_list,self.Scrape_Link_dataset)
        self.data = data
        self.Cleaner(self.data)

# %%
async def get(
    session: aiohttp.ClientSession,
    input_obj:dict,
    url : str
) -> dict:
    print(f"Requesting {url}")
    resp = await session.request('POST', url=url,json=input_obj)

    # Note that this may raise an exception for non-2xx responses
    # You can either handle that here, or pass the exception through
    data = await resp.json()
    print(f"Received data for {url}")
    return data
async def main(input_objs,url, **kwargs):
    # Asynchronous context manager.  Prefer this rather
    # than using a different session for each GET request
    async with aiohttp.ClientSession() as session:
        tasks = []
        for obj in input_objs:
            tasks.append(get(session=session, url=url,input_obj=obj, **kwargs))
        # asyncio.gather() will wait on the entire task set to be
        # completed.  If you want to process results greedily as they come in,
        # loop over asyncio.as_completed()
        data = await asyncio.gather(*tasks, return_exceptions=True)
        return data

# %%
obj = Scrape()
obj.input_obj_maker()
obj.
# Out:
# 10

# %%
obj.obj_list
# Out:
# [{'addParentData': False,
#   'directUrls': ['https://www.instagram.com/rgrimdesign/',
#    'https://www.instagram.com/drveronicakapur_/',
#    'https://www.instagram.com/jasmeetkapany/',
#    'https://www.instagram.com/abhinandankumar2.0/',
#    'https://www.instagram.com/sunshine.sparrows/',
#    'https://www.instagram.com/tenajaiin/',
#    'https://www.instagram.com/nicoleyoungtech/',
#    'https://www.instagram.com/nailsbydvisy/',
#    'https://www.instagram.com/professorofhow/',
#    'https://www.instagram.com/midlife.muse/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'},
#  {'addParentData': False,
#   'directUrls': ['https://www.instagram.com/blackmotherwound/',
#    'https://www.instagram.com/vinali_bhatnagar/',
#    'https://www.instagram.com/theohiogirljaz/',
#    'https://www.instagram.com/harshhrane/',
#    'https://www.instagram.com/vinit_adwani/',
#    'https://www.instagram.com/accountant_she/',
#    'https://www.instagram.com/talwarisha/',
#    'https://www.instagram.com/benanna_love/',
#    'https://www.instagram.com/kanakmishrax/',
#    'https://www.instagram.com/juhi.bhatt/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'},
#  {'addParentData': False,
#   'directUrls': ['https://www.instagram.com/yourseesha/',
#    'https://www.instagram.com/rivyarai_27/',
#    'https://www.instagram.com/nutritionbyrobyn/',
#    'https://www.instagram.com/mehar.labana/',
#    'https://www.instagram.com/dikshuuu/',
#    'https://www.instagram.com/charan_peri/',
#    'https://www.instagram.com/sachinsins/',
#    'https://www.instagram.com/iam_priyanka_kd/',
#    'https://www.instagram.com/rayrooqma/',
#    'https://www.instagram.com/prakritipavani/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'},
#  {'addParentData': False,
#   'directUrls': ['https://www.instagram.com/siimran_siingh/',
#    'https://www.instagram.com/jinal.j.j/',
#    'https://www.instagram.com/somashribhattacharyyaofficial/',
#    'https://www.instagram.com/neelajolene/',
#    'https://www.instagram.com/shaili_bhattacharjee/',
#    'https://www.instagram.com/soumichakraborty_official/',
#    'https://www.instagram.com/nikitabhardwajofficial_11/',
#    'https://www.instagram.com/debchandrima_official/',
#    'https://www.instagram.com/darshanabanik/',
#    'https://www.instagram.com/vedvika_/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'},
#  {'addParentData': False,
#   'directUrls': ['https://www.instagram.com/simplicityandastarter/',
#    'https://www.instagram.com/satyajeetdubey/',
#    'https://www.instagram.com/soniheena__/',
#    'https://www.instagram.com/shreyaapujari/',
#    'https://www.instagram.com/shinepandey/',
#    'https://www.instagram.com/aisharahmed/',
#    'https://www.instagram.com/aadhya_anand/',
#    'https://www.instagram.com/sanvi_bhagat7/',
#    'https://www.instagram.com/urvisingh143/',
#    'https://www.instagram.com/vishakhapandey510/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'},
#  {'addParentData': False,
#   'directUrls': ['https://www.instagram.com/revathi.05/',
#    'https://www.instagram.com/amandeep_sidhu___/',
#    'https://www.instagram.com/nikilalwani_27/',
#    'https://www.instagram.com/sargun_kaur.luthra/',
#    'https://www.instagram.com/akankshaaryaa/',
#    'https://www.instagram.com/am_akankshasingh/',
#    'https://www.instagram.com/sunakshigrover/',
#    'https://www.instagram.com/reel_ananya/',
#    'https://www.instagram.com/rosie.rapp/',
#    'https://www.instagram.com/anushrisurekhamane/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'},
#  {'addParentData': False,
#   'directUrls': ['https://www.instagram.com/sannidhyabaweja/',
#    'https://www.instagram.com/digitalstreamliner/',
#    'https://www.instagram.com/shubhsharma.in/',
#    'https://www.instagram.com/vaibhavv.ai/',
#    'https://www.instagram.com/digital_vamsi/',
#    'https://www.instagram.com/indianfarmer/',
#    'https://www.instagram.com/ahsaassy_/',
#    'https://www.instagram.com/gayatribhardwaj__/',
#    'https://www.instagram.com/futureaiwiki/',
#    'https://www.instagram.com/raisinghani_rahul/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'},
#  {'addParentData': False,
#   'directUrls': ['https://www.instagram.com/classified.ai/',
#    'https://www.instagram.com/storytellingbydata/',
#    'https://www.instagram.com/serviuos/',
#    'https://www.instagram.com/creatorkarro/',
#    'https://www.instagram.com/winkguys/',
#    'https://www.instagram.com/incognito.idea/',
#    'https://www.instagram.com/ai.volve.news/',
#    'https://www.instagram.com/afemalecoder/',
#    'https://www.instagram.com/brandonbutch/',
#    'https://www.instagram.com/viraljain33/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'},
#  {'addParentData': False,
#   'directUrls': ['https://www.instagram.com/viktoria.semaan/',
#    'https://www.instagram.com/_peacefromwithin/',
#    'https://www.instagram.com/aidaily.insights/',
#    'https://www.instagram.com/sketch_dailydose/',
#    'https://www.instagram.com/lanajay_art/',
#    'https://www.instagram.com/shirin_sewani/',
#    'https://www.instagram.com/devika029/',
#    'https://www.instagram.com/sakshiimotwani/',
#    'https://www.instagram.com/cherrychy_/',
#    'https://www.instagram.com/dontmisimi/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'},
#  {'addParentData': False,
#   'directUrls': ['https://www.instagram.com/bindhast_mulgi/',
#    'https://www.instagram.com/artcartbydiksha/',
#    'https://www.instagram.com/sail_shelar/',
#    'https://www.instagram.com/artybuzz/',
#    'https://www.instagram.com/shivamgroverofficial/'],
#   'enhanceUserSearchWithFacebookPage': False,
#   'isUserTaggedFeedURL': False,
#   'resultsLimit': 15,
#   'resultsType': 'details',
#   'searchLimit': 1,
#   'searchType': 'hashtag'}]

# %%
obj_list = input_obj_maker(to_scan,10)

# %%
print(datetime.today().date())
# Out:
# 2024-05-19
